# %% [markdown]
# # 02 - Model Training Experiment
#
# Notebook để thử nghiệm huấn luyện mô hình, đánh giá và lưu artifacts.

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
df = pd.read_csv('../data/creditcard.csv')
print(df.shape)
